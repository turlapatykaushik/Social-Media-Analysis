# %% [markdown]
# # FEDERATION MASKING

# %%
keys = {'WorldGames':'Federation 1','Powerlifting': 'Federation 2', 'Korfball' : 'Federation 3', 'Gymnastics' : 'Federation 4', 'Floorball' : 'Federation 5', 'Fistball' : 'Federation 6', 'Hockey' : 'Federation 7'}

# %% [markdown]
# # INSTAGRAM

# %% [markdown]
# # READ ALL THE FEDERATIONS DATA

# %%
import pandas as pd
WorldGamesDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\The World Games - IWGA\Instagram.xlsx',sheet_name=None)
PowerLiftingDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Powerlifting\Instagram.xlsx',sheet_name=None)
KorfballDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Korfball\Instagram.xlsx',sheet_name=None)
GymnasticsDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Gymnastics\Instagram.xlsx',sheet_name=None)
FloorballDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Floorball\Instagram.xlsx',sheet_name=None)
FistballDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Fistball\Instagram.xlsx',sheet_name=None)
HockeyDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Hockey\Instagram.xlsx',sheet_name=None)

# %% [markdown]
# # READ THE FOLLOWERS DATA FOR ALL THE FEDERATIONS

# %%
followersList = []
#WorldGamesDataFrame['General Profile'].plot('Name','Followers',kind='bar')
followersList.append(WorldGamesDataFrame['General Profile']['Followers'][0])
#PowerLiftingDataFrame['General Profile'].plot('Name','Followers',kind='bar')
followersList.append(PowerLiftingDataFrame['General Profile']['Followers'][0])
#KorfballDataFrame['General Profile'].plot('Name','Followers',kind='bar')
followersList.append(KorfballDataFrame['General Profile']['Followers'][0])
#GymnasticsDataFrame['General Profile'].plot('Name','Followers',kind='bar')
followersList.append(GymnasticsDataFrame['General Profile']['Followers'][0])
#FloorballDataFrame['General Profile'].plot('Name','Followers',kind='bar')
followersList.append(FloorballDataFrame['General Profile']['Followers'][0])
#FistballDataFrame['General Profile'].plot('Name','Followers',kind='bar')
followersList.append(FistballDataFrame['General Profile']['Followers'][0])
followersList.append(HockeyDataFrame['General Profile']['Followers'][0])
# Create a sample dataframe with an text index
plotdata = pd.DataFrame(
    {"Followers": followersList}, 
    index=[keys["WorldGames"], keys["Powerlifting"], keys["Korfball"], keys["Gymnastics"], keys["Floorball"],keys["Fistball"], keys["Hockey"]])
# Plot a bar chart
plotdata.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # READ THE GENDER DATA OF ALL THE FEDERATIONS

# %%
#WorldGamesDataFrame['Gender'].plot('Category','Value',kind='bar')
WorldGamesDataFrame['Gender'].plot.pie(title=keys["WorldGames"],y='Value',autopct='%1.2f%%',labels=WorldGamesDataFrame['Gender']['Category'], legend=False)
#PowerLiftingDataFrame['Gender'].plot('Category','Value',kind='bar')
PowerLiftingDataFrame['Gender'].plot.pie(title=keys["Powerlifting"],y='Value',autopct='%1.2f%%',labels=PowerLiftingDataFrame['Gender']['Category'], legend=False)
#KorfballDataFrame['Gender'].plot('Category','Value',kind='bar')
KorfballDataFrame['Gender'].plot.pie(title=keys["Korfball"],y='Value',autopct='%1.2f%%',labels=KorfballDataFrame['Gender']['Category'], legend=False)
#GymnasticsDataFrame['Gender'].plot('Category','Value',kind='bar')
GymnasticsDataFrame['Gender'].plot.pie(title=keys["Gymnastics"],y='Value',autopct='%1.2f%%',labels=GymnasticsDataFrame['Gender']['Category'], legend=False)
#FloorballDataFrame['Gender'].plot('Category','Value',kind='bar')
FloorballDataFrame['Gender'].plot.pie(title=keys["Floorball"],y='Value',autopct='%1.2f%%',labels=FloorballDataFrame['Gender']['Category'], legend=False)
#FistballDataFrame['Gender'].plot('Category','Value',kind='bar')
FistballDataFrame['Gender'].plot.pie(title=keys["Fistball"],y='Value',autopct='%1.2f%%',labels=FistballDataFrame['Gender']['Category'], legend=False)
HockeyDataFrame['Gender'].plot.pie(title=keys["Hockey"],y='Value',autopct='%1.2f%%',labels=HockeyDataFrame['Gender']['Category'], legend=False)
# Out:
# <AxesSubplot:title={'center':'Hockey'}, ylabel='Value'>

# %% [markdown]
# # READ THE AGE DATA FOR ALL THE FEDERATIONS

# %%
#WorldGamesDataFrame['Age'].plot('Category','Value',kind='bar')
WorldGamesDataFrame['Age'].plot.pie(title="World Games",y='Value',autopct='%1.0f%%',labels=WorldGamesDataFrame['Age']['Category'], legend=False)
#PowerLiftingDataFrame['Age'].plot('Category','Value',kind='bar')
PowerLiftingDataFrame['Age'].plot.pie(title="Powerlifting",y='Value',autopct='%1.0f%%',labels=PowerLiftingDataFrame['Age']['Category'], legend=False)
#KorfballDataFrame['Age'].plot('Category','Value',kind='bar')
KorfballDataFrame['Age'].plot.pie(title="Korfball",y='Value',autopct='%1.0f%%',labels=KorfballDataFrame['Age']['Category'], legend=False)
#GymnasticsDataFrame['Age'].plot('Category','Value',kind='bar')
GymnasticsDataFrame['Age'].plot.pie(title="Gymnastics",y='Value',autopct='%1.0f%%',labels=GymnasticsDataFrame['Age']['Category'], legend=False)
#FloorballDataFrame['Age'].plot('Category','Value',kind='bar')
FloorballDataFrame['Age'].plot.pie(title="Floorball",y='Value',autopct='%1.0f%%',labels=FloorballDataFrame['Age']['Category'], legend=False)
#FistballDataFrame['Age'].plot('Category','Value',kind='bar')
FistballDataFrame['Age'].plot.pie(title="Fistball",y='Value',autopct='%1.0f%%',labels=FistballDataFrame['Age']['Category'], legend=False)
HockeyDataFrame['Age'].plot.pie(title="Hockey",y='Value',autopct='%1.0f%%',labels=HockeyDataFrame['Age']['Category'], legend=False)
# Out:
# <AxesSubplot:title={'center':'Hockey'}, ylabel='Value'>

# %% [markdown]
# # READ THE COUNTRIES DATA FOR ALL THE FEDERATIONS

# %%
#WorldGamesDataFrame['Countries'].plot('Category','Value',kind='bar')
WorldGamesDataFrame['Countries'].plot.pie(title="World Games",y='Value',autopct='%1.2f%%',labels=WorldGamesDataFrame['Countries']['Name'], legend=False)
#PowerLiftingDataFrame['Countries'].plot('Category','Value',kind='bar')
PowerLiftingDataFrame['Countries'].plot.pie(title="Powerlifting",y='Value',autopct='%1.2f%%',labels=PowerLiftingDataFrame['Countries']['Name'], legend=False)
#KorfballDataFrame['Countries'].plot('Category','Value',kind='bar')
KorfballDataFrame['Countries'].plot.pie(title="Korfball",y='Value',autopct='%1.2f%%',labels=KorfballDataFrame['Countries']['Name'], legend=False)
#GymnasticsDataFrame['Countries'].plot('Category','Value',kind='bar')
GymnasticsDataFrame['Countries'].plot.pie(title="Gymnastics",y='Value',autopct='%1.2f%%',labels=GymnasticsDataFrame['Countries']['Name'], legend=False)
#FloorballDataFrame['Countries'].plot('Category','Value',kind='bar')
FloorballDataFrame['Countries'].plot.pie(title="Floorball",y='Value',autopct='%1.2f%%',labels=FloorballDataFrame['Countries']['Name'], legend=False)
#FistballDataFrame['Countries'].plot('Category','Value',kind='bar')
FistballDataFrame['Countries'].plot.pie(title="Fistball",y='Value',autopct='%1.2f%%',labels=FistballDataFrame['Countries']['Name'], legend=False)
HockeyDataFrame['Countries'].plot.pie(title="Hockey",y='Value',autopct='%1.2f%%',labels=HockeyDataFrame['Countries']['Name'], legend=False)
# Out:
# <AxesSubplot:title={'center':'Hockey'}, ylabel='Value'>

# %% [markdown]
# # Singapore and Floorball
#
# - 1994 - Floorball was introduced to the mass community by Mr Stefan Dahlgren. At that time, the sport was known as “Streetbandy” 1995 - The Singapore Floorball Association (SFA) was formed 1996 - Singapore sends 1st national team to compete in the World Floorball Championship (WFC) held in Sweden.1997 - The inaugural National Floorball League was played, featuring 6 Men’s teams and 4 Ladies’ teams. 1998 - Singapore participated in the Men’s WFC in Czech Republic.1999 - Singapore sent its first national women’s team to compete in the Women’s WFC in Sweden. The first international floorball tournament in Singapore was organised with the Singapore International Floorball Championships, which featured Sweden and Finland. 2001 - Singapore participated in the Women’s WFC in Latvia, finishing with the bronze medal in the B Division. 2002 - Singapore participated in the Men’s WFC in Finland, achieving it first ever win for the Men in a WFC tournament by beating Malaysia. 2003 - Singapore participated in the Women’s WFC in Switzerland.
# - Singapore to host the Women's World Championship in 2023
# - National women's team get 12,000 USD boost from Excelsior Financial
# - SINGAPORE MEN'S TEAM RECEIVE 15,000 SGD FROM EXCELSIOR FINANCIAL GROUP
