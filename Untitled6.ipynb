# %% [markdown]
# # FEDERATION MASKING

# %%
keys = {'WorldGames':'Federation 1','Powerlifting': 'Federation 2', 'Korfball' : 'Federation 3', 'Gymnastics' : 'Federation 4', 'Floorball' : 'Federation 5', 'Fistball' : 'Federation 6', 'Hockey' : 'Federation 7', 'Tug Of War': 'Federation 8', 'CEB' : 'Federation 9', 'UMB' : 'Federation 10'}

# %% [markdown]
# # FACEBOOK

# %% [markdown]
# # READ THE GENDER DATA OF ALL FEDERATIONS

# %%
import matplotlib.pyplot as plt

my_data = [66,33]
my_labels = 'Men','Women'
plt.pie(my_data,labels=my_labels,autopct='%1.1f%%')
plt.title(keys['Tug Of War'])
plt.axis('equal')
plt.show()

my_data = [86,14]
my_labels = 'Men','Women'
plt.pie(my_data,labels=my_labels,autopct='%1.1f%%')
plt.title(keys['Powerlifting'])
plt.axis('equal')
plt.show()

my_data = [55,44]
my_labels = 'Men','Women'
plt.pie(my_data,labels=my_labels,autopct='%1.1f%%')
plt.title(keys['Korfball'])
plt.axis('equal')
plt.show()

my_data = [42,57]
my_labels = 'Men','Women'
plt.pie(my_data,labels=my_labels,autopct='%1.1f%%')
plt.title(keys['Gymnastics'])
plt.axis('equal')
plt.show()

my_data = [76,24]
my_labels = 'Men','Women'
plt.pie(my_data,labels=my_labels,autopct='%1.1f%%')
plt.title(keys['Floorball'])
plt.axis('equal')
plt.show()

my_data = [63,36]
my_labels = 'Men','Women'
plt.pie(my_data,labels=my_labels,autopct='%1.1f%%')
plt.title(keys['Fistball'])
plt.axis('equal')
plt.show()

my_data = [89,10]
my_labels = 'Men','Women'
plt.pie(my_data,labels=my_labels,autopct='%1.1f%%')
plt.title(keys['CEB'])
plt.axis('equal')
plt.show()

my_data = [94,5]
my_labels = 'Men','Women'
plt.pie(my_data,labels=my_labels,autopct='%1.1f%%')
plt.title(keys['UMB'])
plt.axis('equal')
plt.show()

# %% [markdown]
# # ANALYSING THE PAID PROMOTIONS

# %% [markdown]
# # FIRST PERIOD

# %%
import pandas as pd
TugOfWarDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Tug of War\Facebook\TWIF Facebook post data 1 July 2020 - 25 December 2020.xlsx',sheet_name=None)
WorldGamesDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\The World Games - IWGA\Facebook\Facebook Insights Data Export (Post Level 4) - The World Games - 2021-02-17.xlsx',sheet_name=None)
PowerLiftingDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Powerlifting\Facebook\Facebook Insights Data Export (Post Level) - International Powerlifting Federation - IPF - 2021-02-05 (3).xlsx',sheet_name=None)
KorfballDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Korfball\Facebook\FB Excel Stats\1 July 2020 to 25 Dec 2020\Facebook Insights Data Export (Post Level) - Korfball.org - 1 Jul 2020 to 25 Dec 2020.xlsx',sheet_name=None)
GymnasticsDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Gymnastics\Facebook\1 july 25 dec 2020\Facebook Insights Data Export (Post Level) - International Gymnastics Federation - FIG - 2021-02-06.xlsx',sheet_name=None)
HockeyDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Hockey\Facebook\Facebook Insights Data Export (Post Level) - International Hockey Federation (FIH) - 2021-02-04 (2).xlsx',sheet_name=None)
FloorballDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Floorball\Facebook\1st January 2020 - 28th June 2020\Facebook Insights Data Export - International Floorball Federation (IFF) - 2021-02-04 (2).xlsx',sheet_name=None)
FistballDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Fistball\Facebook\Posts_4_Facebook Insights Data Export (Post Level) - IFA - International Fistball Association - 2021-02-04.xlsx',sheet_name=None)
CEBDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Billiards\CEB\Facebook\CEB_Post Data_July-Dec 2020.xlsx',sheet_name=None)
UMBDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Billiards\UMB\Facebook\UMB_Post Data_Jul-Dec 2020.xlsx',sheet_name=None)

# %% [markdown]
# # READ THE Lifetime Post Consumers by type SHEET

# %%
TugOfWarLifetimePostConsumersbytype = TugOfWarDataFrame['Lifetime Post Consumers by type']
WorldGamesLifetimePostConsumersbytype = WorldGamesDataFrame['Lifetime Post Consumers by type']
PowerLiftingLifetimePostConsumersbytype = PowerLiftingDataFrame['Lifetime Post Consumers by type']
KorfballLifetimePostConsumersbytype = KorfballDataFrame['Lifetime Post Consumers by type']
GymnasticsLifetimePostConsumersbytype = GymnasticsDataFrame['Lifetime Post Consumers by type']
HockeyLifetimePostConsumersbytype = HockeyDataFrame['Lifetime Post Consumers by type']
#FloorballLifetimePostConsumersbytype = FloorballDataFrame['Lifetime Post Consumers by type']
#FistballKeyMetrics = FistballDataFrame['Posts_1_Facebook Insights Data ']
CEBLifetimePostConsumersbytype = CEBDataFrame['Lifetime Post Consumers by type']
UMBLifetimePostConsumersbytype = UMBDataFrame['Lifetime Post Consumers by type']

# %% [markdown]
# # READ THE Lifetime Post Stories by act... SHEET

# %%
TugOfWarLifetimePostStoriesbyact = TugOfWarDataFrame['Lifetime Post Stories by act...']
WorldGamesLifetimePostStoriesbyact = WorldGamesDataFrame['Lifetime Post Stories by act...']
PowerLiftingLifetimePostStoriesbyact = PowerLiftingDataFrame['Lifetime Post Stories by act...']
KorfballLifetimePostStoriesbyact = KorfballDataFrame['Lifetime Post Stories by act...']
GymnasticsLifetimePostStoriesbyact = GymnasticsDataFrame['Lifetime Post Stories by act...']
HockeyLifetimePostStoriesbyact = HockeyDataFrame['Lifetime Post Stories by act...']
#FloorballLifetimePostStoriesbyact = FloorballDataFrame['Lifetime Post Stories by act...']
#FistballKeyMetrics = FistballDataFrame['Posts_1_Facebook Insights Data ']
CEBLifetimePostStoriesbyact = CEBDataFrame['Lifetime Post Stories by act...']
UMBLifetimePostStoriesbyact = UMBDataFrame['Lifetime Post Stories by act...']

# %%
FloorballLifetimePostStoriesbyact.columns
# Out:
# Index(['Description', 'Post ID', 'Permalink', 'Post Message', 'Type',
#        'Countries', 'Languages', 'Posted', 'Audience targeting', 'share',
#        'like', 'comment'],
#       dtype='object')

# %%
merged_inner = pd.merge(left=UMBLifetimePostConsumersbytype, right=UMBLifetimePostStoriesbyact, left_on='Post ID', right_on='Post ID')

# %%
merged_inner.loc[(merged_inner['Type_x']=='Link')]
# Out:
#    Description_x                           Post ID  \
# 2            NaN  192612067568788_1748921811937798
# 3            NaN  192612067568788_1746070638889582
# 4            NaN  192612067568788_1742465049250141
# 5            NaN  192612067568788_1737411399755506
# 6            NaN  192612067568788_1734200663409913
# 7            NaN  192612067568788_1721607971335849
# 8            NaN  192612067568788_1716913708471942
# 9            NaN  192612067568788_1709279129235400
# 10           NaN  192612067568788_1708343362662310
# 11           NaN  192612067568788_1707258426104137
# 12           NaN  192612067568788_1705490966280883
# 13           NaN  192612067568788_1701315603365086
# 14           NaN  192612067568788_1700276846802295
# 15           NaN  192612067568788_1695519213944725
# 17           NaN  192612067568788_1693721997457780
# 18           NaN  192612067568788_1692858180877495
# 19           NaN  192612067568788_1691944110968902
# ...

# %%
merged_inner.loc[(merged_inner['Type_x']=='Link') & (merged_inner['share']>0) & (merged_inner['link clicks'].isna())]
# Out:
# Empty DataFrame
# Columns: [Description_x, Post ID, Permalink_x, Post Message_x, Type_x, Countries_x, Languages_x, Posted_x, Audience Targeting_x, other clicks, photo view, link clicks, Description_y, Permalink_y, Post Message_y, Type_y, Countries_y, Languages_y, Posted_y, Audience Targeting_y, like, share, comment]
# Index: []
#
# [0 rows x 23 columns]

# %%
listOf

# %% [markdown]
# # READ THE KEY METRICS SHEET

# %%
TugOfWarKeyMetrics = TugOfWarDataFrame['Key Metrics']
WorldGamesKeyMetrics = WorldGamesDataFrame['Key Metrics']
PowerLiftingKeyMetrics = PowerLiftingDataFrame['Key Metrics']
KorfballKeyMetrics = KorfballDataFrame['Key Metrics']
GymnasticsKeyMetrics = GymnasticsDataFrame['Key Metrics']
HockeyKeyMetrics = HockeyDataFrame['Key Metrics']
FloorballKeyMetrics = FloorballDataFrame['Key Metrics']
FistballKeyMetrics = FistballDataFrame['Posts_1_Facebook Insights Data ']
CEBKeyMetrics = CEBDataFrame['Key Metrics']
UMBKeyMetrics = UMBDataFrame['Key Metrics']

# %%
listOfKeyMetrics = [TugOfWarKeyMetrics,WorldGamesKeyMetrics,PowerLiftingKeyMetrics,KorfballKeyMetrics,GymnasticsKeyMetrics,HockeyKeyMetrics, FloorballKeyMetrics,FistballKeyMetrics, CEBKeyMetrics, UMBKeyMetrics]
for KeyMetrics in listOfKeyMetrics:
    count=0
    for index, row in KeyMetrics.iterrows():
        if index!=0:
            if(row['Lifetime Post Paid Reach']>0):
                count+=1
                #print(row['Post Message'])
                print("--------------------------------")
    print("Total number of paid posts is ",count)
    print("======================================")
# Out:
# Total number of paid posts is  0
# ...
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# Total number of paid posts is  9
# ...
# --------------------------------
# --------------------------------
# Total number of paid posts is  2
# ...
# Total number of paid posts is  0
# ...
# Total number of paid posts is  0
# ...
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# ...

# %% [markdown]
# # SECOND PERIOD

# %%
import pandas as pd
TugOfWarDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Tug of War\Facebook\TWIF Facebook post data 1 July 2019 - 25 December 2019.xlsx',sheet_name=None)
WorldGamesDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\The World Games - IWGA\Facebook\Facebook Insights Data Export (Post Level2) - The World Games - 2021-02-17.xlsx',sheet_name=None)
PowerLiftingDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Powerlifting\Facebook\Facebook Insights Data Export (Post Level) - International Powerlifting Federation - IPF - 2021-02-05 (1).xlsx',sheet_name=None)
KorfballDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Korfball\Facebook\FB Excel Stats\1 July 2019 to 25 Dec 2019\Facebook Insights Data Export (Post Level) - Korfball.org - 1 July 2019 to 25 Dec 2019.xlsx',sheet_name=None)
GymnasticsDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Gymnastics\Facebook\01 july 25 dec 2019\Facebook Insights Data Export (Post Level) - International Gymnastics Federation - FIG - 2021-02-06 (1).xlsx',sheet_name=None)
HockeyDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Hockey\Facebook\Facebook Insights Data Export (Post Level) - International Hockey Federation (FIH) - 2021-02-04 (1).xlsx',sheet_name=None)
FloorballDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Floorball\Facebook\1st July 2019 - 25th December 2019\Facebook Insights Data Export (Post Level) - International Floorball Federation (IFF) - 2021-02.xlsx',sheet_name=None)
FistballDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Fistball\Facebook\Posts_2_Facebook Insights Data Export (Post Level) - IFA - International Fistball Association - 2021-02-04.xlsx',sheet_name=None)
CEBDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Billiards\CEB\Facebook\CEB_Post Data_July-Dec 2019.xlsx',sheet_name=None)
UMBDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Billiards\UMB\Facebook\UMB_Post Data_Jul-Dec 2019.xlsx',sheet_name=None)

# %% [markdown]
# # READ THE KEY METRICS SHEET

# %%
TugOfWarKeyMetrics = TugOfWarDataFrame['Key Metrics']
WorldGamesKeyMetrics = WorldGamesDataFrame['Key Metrics']
PowerLiftingKeyMetrics = PowerLiftingDataFrame['Key Metrics']
KorfballKeyMetrics = KorfballDataFrame['Key Metrics']
GymnasticsKeyMetrics = GymnasticsDataFrame['Key Metrics']
HockeyKeyMetrics = HockeyDataFrame['Key Metrics']
FloorballKeyMetrics = FloorballDataFrame['Key Metrics']
FistballKeyMetrics = FistballDataFrame['Posts_2_Facebook Insights Data ']
CEBKeyMetrics = CEBDataFrame['Key Metrics']
UMBKeyMetrics = UMBDataFrame['Key Metrics']

# %%
listOfKeyMetrics = [TugOfWarKeyMetrics,WorldGamesKeyMetrics,PowerLiftingKeyMetrics,KorfballKeyMetrics,GymnasticsKeyMetrics,HockeyKeyMetrics, FloorballKeyMetrics,FistballKeyMetrics, CEBKeyMetrics, UMBKeyMetrics]
for KeyMetrics in listOfKeyMetrics:
    count=0
    for index, row in KeyMetrics.iterrows():
        if index!=0:
            if(row['Lifetime Post Paid Reach']>0):
                count+=1
                #print(row['Post Message'])
                print("--------------------------------")
    print("Total number of paid posts is ",count)
    print("======================================")
# Out:
# Total number of paid posts is  0
# ...
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# Total number of paid posts is  12
# ...
# Total number of paid posts is  0
# ...
# Total number of paid posts is  0
# ...
# Total number of paid posts is  0
# ...
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# ...

# %% [markdown]
# # THIRD PERIOD

# %%
import pandas as pd
TugOfWarDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Tug of War\Facebook\TWIF Facebook post data 1 January 2020 - 28 June 2020.xlsx',sheet_name=None)
WorldGamesDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\The World Games - IWGA\Facebook\Facebook Insights Data Export (Post Level 3) - The World Games - 2021-02-17.xlsx',sheet_name=None)
PowerLiftingDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Powerlifting\Facebook\Facebook Insights Data Export (Post Level) - International Powerlifting Federation - IPF - 2021-02-05 (2).xlsx',sheet_name=None)
KorfballDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Korfball\Facebook\FB Excel Stats\1 Jan 2020 to 28 June 2020\Facebook Insights Data Export (Post Level) - Korfball.org - 1 Jan 2020 to 28 June 2020.xlsx',sheet_name=None)
GymnasticsDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Gymnastics\Facebook\1 jan 2020 28 june 2020\Facebook Insights Data Export (Post Level) - International Gymnastics Federation - FIG - 2021-02-06 (1).xlsx',sheet_name=None)
FloorballDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Floorball\Facebook\1st January 2020 - 28th June 2020\Facebook Insights Data Export - International Floorball Federation (IFF) - 2021-02-04 (2).xlsx',sheet_name=None)
FistballDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Fistball\Facebook\Posts_3_Facebook Insights Data Export (Post Level) - IFA - International Fistball Association - 2021-02-04.xlsx',sheet_name=None)
CEBDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Billiards\CEB\Facebook\CEB_Post Data_Jan-June 2020.xlsx',sheet_name=None)
UMBDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Billiards\UMB\Facebook\UMB_Post Data_Jan-June 2020.xlsx',sheet_name=None)

# %% [markdown]
# # READ THE KEY METRICS SHEET

# %%
TugOfWarKeyMetrics = TugOfWarDataFrame['Key Metrics']
WorldGamesKeyMetrics = WorldGamesDataFrame['Key Metrics']
PowerLiftingKeyMetrics = PowerLiftingDataFrame['Key Metrics']
KorfballKeyMetrics = KorfballDataFrame['Key Metrics']
GymnasticsKeyMetrics = GymnasticsDataFrame['Key Metrics']
FloorballKeyMetrics = FloorballDataFrame['Key Metrics']
FistballKeyMetrics = FistballDataFrame['Posts_3_Facebook Insights Data ']
CEBKeyMetrics = CEBDataFrame['Key Metrics']
UMBKeyMetrics = UMBDataFrame['Key Metrics']

# %%
listOfKeyMetrics = [TugOfWarKeyMetrics,WorldGamesKeyMetrics,PowerLiftingKeyMetrics,KorfballKeyMetrics,GymnasticsKeyMetrics,FloorballKeyMetrics,FistballKeyMetrics, CEBKeyMetrics, UMBKeyMetrics]
for KeyMetrics in listOfKeyMetrics:
    count=0
    try:
        for index, row in KeyMetrics.iterrows():
            if index!=0:
                if(row['Lifetime Post Paid Reach']>0):
                    count+=1
                    print(row['Post Message'])
                    print("--------------------------------")
        print("Total number of paid posts is ",count)
        print("======================================")
    except:
        print("Total number of paid posts is ",count)
        print("======================================")
# Out:
# Total number of paid posts is  0
# ...
# "It's like the Olympics, you know!" Muaythai fighter Sofia Olofsson joins our We Are The World Games interview series - her interview premieres on YouTube in 30 minutes!   Make sure not to miss it - you can of course watch it later on too: https://www.youtube.com/watch?v=YU2TduqthNI  #WeAreTheWorldGames #RoadtoBHM #TWG2022 #Muaythai The World Games 2022 Birmingham IFMA - International Federation of Muaythai Associations Svenska Muaythai-Förbundet Svenska Budo & Kampsportsförbundet
# --------------------------------
# Bowling star AJ Johnson 🇺🇸 looks forward to The World Games 2022 on home soil! Two years to go - we cannot wait!   #RoadtoBHM #WeAreTheWorldGames #TWG2022 #Bowling World Bowling The Sport of Bowling – USBC
# --------------------------------
# ...

# %% [markdown]
# # FORTH PERIOD

# %%
import pandas as pd
TugOfWarDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Tug of War\Facebook\TWIF Facebook post data 1 July 2020 - 25 December 2020.xlsx',sheet_name=None)
WorldGamesDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\The World Games - IWGA\Facebook\Facebook Insights Data Export (Post Level 4) - The World Games - 2021-02-17.xlsx',sheet_name=None)
PowerLiftingDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Powerlifting\Facebook\Facebook Insights Data Export (Post Level) - International Powerlifting Federation - IPF - 2021-02-05 (3).xlsx',sheet_name=None)
KorfballDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Korfball\Facebook\FB Excel Stats\1 July 2020 to 25 Dec 2020\Facebook Insights Data Export (Post Level) - Korfball.org - 1 Jul 2020 to 25 Dec 2020.xlsx',sheet_name=None)
GymnasticsDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Gymnastics\Facebook\1 july 25 dec 2020\Facebook Insights Data Export (Post Level) - International Gymnastics Federation - FIG - 2021-02-06.xlsx',sheet_name=None)
HockeyDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Hockey\Facebook\Facebook Insights Data Export (Post Level) - International Hockey Federation (FIH) - 2021-02-04 (2).xlsx',sheet_name=None)
FloorballDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Floorball\Facebook\1st January 2020 - 28th June 2020\Facebook Insights Data Export - International Floorball Federation (IFF) - 2021-02-04 (2).xlsx',sheet_name=None)
FistballDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Fistball\Facebook\Posts_4_Facebook Insights Data Export (Post Level) - IFA - International Fistball Association - 2021-02-04.xlsx',sheet_name=None)
CEBDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Billiards\CEB\Facebook\CEB_Post Data_July-Dec 2020.xlsx',sheet_name=None)
UMBDataFrame = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Billiards\UMB\Facebook\UMB_Post Data_Jul-Dec 2020.xlsx',sheet_name=None)

# %% [markdown]
# # READ THE KEY METRICS SHEET

# %%
TugOfWarKeyMetrics = TugOfWarDataFrame['Key Metrics']
WorldGamesKeyMetrics = WorldGamesDataFrame['Key Metrics']
PowerLiftingKeyMetrics = PowerLiftingDataFrame['Key Metrics']
KorfballKeyMetrics = KorfballDataFrame['Key Metrics']
GymnasticsKeyMetrics = GymnasticsDataFrame['Key Metrics']
HockeyKeyMetrics = HockeyDataFrame['Key Metrics']

FloorballKeyMetrics = FloorballDataFrame['Key Metrics']
FistballKeyMetrics = FistballDataFrame['Posts_4_Facebook Insights Data ']
CEBKeyMetrics = CEBDataFrame['Key Metrics']
UMBKeyMetrics = UMBDataFrame['Key Metrics']

# %%
listOfKeyMetrics = [TugOfWarKeyMetrics,WorldGamesKeyMetrics,PowerLiftingKeyMetrics,KorfballKeyMetrics,GymnasticsKeyMetrics,HockeyKeyMetrics,FloorballKeyMetrics,FistballKeyMetrics, CEBKeyMetrics, UMBKeyMetrics]
for KeyMetrics in listOfKeyMetrics:
    count=0
    try:
        for index, row in KeyMetrics.iterrows():
            if index!=0:
                if(row['Lifetime Post Paid Reach']>0):
                    count+=1
                    #print(row['Post Message'])
                    print("--------------------------------")
        print("Total number of paid posts is ",count)
        print("======================================")
    except:
        print("Total number of paid posts is ",count)
        print("======================================")
# Out:
# Total number of paid posts is  0
# ...
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# --------------------------------
# ...

# %% [markdown]
# ### TugOfWar Total Paid Posts = 0+0+0+0 = 0
# ### WorldGames Total Paid Posts = 9+12+42+75 = 138
# ### Powerlifting Total Paid Posts = 2+0+0+0 = 2
# ### Korfball Total Paid Posts = 0+0+0+0 = 0
# ### Gymnastics Total Paid Posts = 0+0+33+61 = 94
# ### Hockey Total Paid Posts = 325+204+0+91 = 620 (Third Period data was not available. Assuming it is zero)
# ### Floorball Total Paid Posts = 0+0+0+0 = 0 (Third and Forth Period data was not available. I assumed it is zero based on last two)
# ### Fistball Total Paid Posts = 1+0+0+1 = 2
# ### CEB Total Paid Posts = 0+0+0+0 = 0
# ### UMB Total Paid Posts = 0+0+0+0 = 0

# %%
plotdata = pd.DataFrame(
    {"Total Promoted Posts in last two years": [138,2,0,94,0,2,620,0,0,0]}, 
    index=[keys["WorldGames"], keys['Powerlifting'],keys["Korfball"], keys["Gymnastics"],keys["Floorball"],keys["Fistball"], keys["Hockey"], keys["Tug Of War"], keys['CEB'],keys['UMB']])
# Plot a bar chart
plotdata.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # THIRD PERIOD - TYPES

# %%
import pandas as pd
TugOfWarDataFrame_3 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Tug of War\Facebook\TWIF Facebook post data 1 January 2020 - 28 June 2020.xlsx',sheet_name=None)
WorldGamesDataFrame_3 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\The World Games - IWGA\Facebook\Facebook Insights Data Export (Post Level 3) - The World Games - 2021-02-17.xlsx',sheet_name=None)
PowerLiftingDataFrame_3 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Powerlifting\Facebook\Facebook Insights Data Export (Post Level) - International Powerlifting Federation - IPF - 2021-02-05 (2).xlsx',sheet_name=None)
KorfballDataFrame_3 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Korfball\Facebook\FB Excel Stats\1 Jan 2020 to 28 June 2020\Facebook Insights Data Export (Post Level) - Korfball.org - 1 Jan 2020 to 28 June 2020.xlsx',sheet_name=None)
GymnasticsDataFrame_3 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Gymnastics\Facebook\1 jan 2020 28 june 2020\Facebook Insights Data Export (Post Level) - International Gymnastics Federation - FIG - 2021-02-06 (1).xlsx',sheet_name=None)
FloorballDataFrame_3 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Floorball\Facebook\1st January 2020 - 28th June 2020\Facebook Insights Data Export - International Floorball Federation (IFF) - 2021-02-04 (2).xlsx',sheet_name=None)
FistballDataFrame_3 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Fistball\Facebook\Posts_3_Facebook Insights Data Export (Post Level) - IFA - International Fistball Association - 2021-02-04.xlsx',sheet_name=None)
CEBDataFrame_3 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Billiards\CEB\Facebook\CEB_Post Data_Jan-June 2020.xlsx',sheet_name=None)
UMBDataFrame_3 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Billiards\UMB\Facebook\UMB_Post Data_Jan-June 2020.xlsx',sheet_name=None)

# %%
TugOfWarKeyMetrics_3 = TugOfWarDataFrame_3['Key Metrics']
WorldGamesKeyMetrics_3 = WorldGamesDataFrame_3['Key Metrics']
PowerLiftingKeyMetrics_3 = PowerLiftingDataFrame_3['Key Metrics']
KorfballKeyMetrics_3 = KorfballDataFrame_3['Key Metrics']
GymnasticsKeyMetrics_3 = GymnasticsDataFrame_3['Key Metrics']
FloorballKeyMetrics_3 = FloorballDataFrame_3['Key Metrics']
FistballKeyMetrics_3 = FistballDataFrame_3['Posts_3_Facebook Insights Data ']
CEBKeyMetrics_3 = CEBDataFrame_3['Key Metrics']
UMBKeyMetrics_3 = UMBDataFrame_3['Key Metrics']

# %%
listOfKeyMetrics_3 = [TugOfWarKeyMetrics_3,WorldGamesKeyMetrics_3,PowerLiftingKeyMetrics_3,KorfballKeyMetrics_3,GymnasticsKeyMetrics_3,FloorballKeyMetrics_3,FistballKeyMetrics_3, CEBKeyMetrics_3, UMBKeyMetrics_3]
for KeyMetrics_3 in listOfKeyMetrics_3:
    try:
        print(KeyMetrics_3['Type'].value_counts())
    except:
        print("Floorball does not have data for this period")
# Out:
# Photo          119
# Status          96
# Link            48
# SharedVideo     28
# Name: Type, dtype: int64
# Video          86
# Photo          70
# Link           20
# SharedVideo    10
# Name: Type, dtype: int64
# Video          28
# Photo          20
# Link           15
# SharedVideo    15
# Status          2
# Name: Type, dtype: int64
# Photo          185
# Video          149
# Link            38
# SharedVideo     27
# Status           5
# Name: Type, dtype: int64
# Photo          168
# Video          115
# SharedVideo     10
# Link             4
# Name: Type, dtype: int64
# Floorball does not have data for this period
# Photo          17
# Video          15
# Link            2
# Status          2
# SharedVideo     1
# Name: Type, dtype: int64
# Photo          53
# Link           10
# Video           2
# Status          1
# SharedVideo     1
# Name: Type, dtype: int64
# Link     11
# Photo     3
# Name: Type, dtype: int64

# %% [markdown]
# # FORTH PERIOD - TYPES

# %%
import pandas as pd
TugOfWarDataFrame_4 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Tug of War\Facebook\TWIF Facebook post data 1 July 2020 - 25 December 2020.xlsx',sheet_name=None)
WorldGamesDataFrame_4 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\The World Games - IWGA\Facebook\Facebook Insights Data Export (Post Level 4) - The World Games - 2021-02-17.xlsx',sheet_name=None)
PowerLiftingDataFrame_4 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Powerlifting\Facebook\Facebook Insights Data Export (Post Level) - International Powerlifting Federation - IPF - 2021-02-05 (3).xlsx',sheet_name=None)
KorfballDataFrame_4 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Korfball\Facebook\FB Excel Stats\1 July 2020 to 25 Dec 2020\Facebook Insights Data Export (Post Level) - Korfball.org - 1 Jul 2020 to 25 Dec 2020.xlsx',sheet_name=None)
GymnasticsDataFrame_4 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Gymnastics\Facebook\1 july 25 dec 2020\Facebook Insights Data Export (Post Level) - International Gymnastics Federation - FIG - 2021-02-06.xlsx',sheet_name=None)
FloorballDataFrame_4 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Floorball\Facebook\1st January 2020 - 28th June 2020\Facebook Insights Data Export - International Floorball Federation (IFF) - 2021-02-04 (2).xlsx',sheet_name=None)
FistballDataFrame_4 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Fistball\Facebook\Posts_4_Facebook Insights Data Export (Post Level) - IFA - International Fistball Association - 2021-02-04.xlsx',sheet_name=None)
CEBDataFrame_4 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Billiards\CEB\Facebook\CEB_Post Data_July-Dec 2020.xlsx',sheet_name=None)
UMBDataFrame_4 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Billiards\UMB\Facebook\UMB_Post Data_Jul-Dec 2020.xlsx',sheet_name=None)

# %%
TugOfWarKeyMetrics_4 = TugOfWarDataFrame_4['Key Metrics']
WorldGamesKeyMetrics_4 = WorldGamesDataFrame_4['Key Metrics']
PowerLiftingKeyMetrics_4 = PowerLiftingDataFrame_4['Key Metrics']
KorfballKeyMetrics_4 = KorfballDataFrame_4['Key Metrics']
GymnasticsKeyMetrics_4 = GymnasticsDataFrame_4['Key Metrics']
FloorballKeyMetrics_4 = FloorballDataFrame_4['Key Metrics']
FistballKeyMetrics_4 = FistballDataFrame_4['Posts_4_Facebook Insights Data ']
CEBKeyMetrics_4 = CEBDataFrame_4['Key Metrics']
UMBKeyMetrics_4 = UMBDataFrame_4['Key Metrics']

# %%
listOfKeyMetrics_4 = [TugOfWarKeyMetrics_4,WorldGamesKeyMetrics_4,PowerLiftingKeyMetrics_4,KorfballKeyMetrics_4,GymnasticsKeyMetrics_4,FloorballKeyMetrics_4,FistballKeyMetrics_4, CEBKeyMetrics_4, UMBKeyMetrics_4]
for KeyMetrics_4 in listOfKeyMetrics_4:
    try:
        print(KeyMetrics_4['Type'].value_counts())
    except:
        print("Floorball does not have data for this period")
# Out:
# Photo          85
# Link           22
# SharedVideo    18
# Status          5
# Name: Type, dtype: int64
# Photo          79
# Video          31
# Link            5
# SharedVideo     5
# Name: Type, dtype: int64
# Link           17
# Photo          16
# Video           6
# SharedVideo     5
# Status          4
# Name: Type, dtype: int64
# Photo          90
# Video          58
# SharedVideo    23
# Link           18
# Status          1
# Name: Type, dtype: int64
# Video          140
# Photo          107
# SharedVideo     16
# Link             2
# Status           1
# Name: Type, dtype: int64
# Floorball does not have data for this period
# Photo          30
# Video          15
# Link            6
# SharedVideo     2
# Status          1
# Name: Type, dtype: int64
# Photo    10
# Link      1
# Name: Type, dtype: int64
# Link     48
# Photo     5
# Name: Type, dtype: int64

# %% [markdown]
# # SECOND PERIOD - TYPES

# %%
import pandas as pd
TugOfWarDataFrame_2 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Tug of War\Facebook\TWIF Facebook post data 1 July 2019 - 25 December 2019.xlsx',sheet_name=None)
WorldGamesDataFrame_2 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\The World Games - IWGA\Facebook\Facebook Insights Data Export (Post Level2) - The World Games - 2021-02-17.xlsx',sheet_name=None)
PowerLiftingDataFrame_2 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Powerlifting\Facebook\Facebook Insights Data Export (Post Level) - International Powerlifting Federation - IPF - 2021-02-05 (1).xlsx',sheet_name=None)
KorfballDataFrame_2 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Korfball\Facebook\FB Excel Stats\1 July 2019 to 25 Dec 2019\Facebook Insights Data Export (Post Level) - Korfball.org - 1 July 2019 to 25 Dec 2019.xlsx',sheet_name=None)
GymnasticsDataFrame_2 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Gymnastics\Facebook\01 july 25 dec 2019\Facebook Insights Data Export (Post Level) - International Gymnastics Federation - FIG - 2021-02-06 (1).xlsx',sheet_name=None)
FloorballDataFrame_2 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Floorball\Facebook\1st July 2019 - 25th December 2019\Facebook Insights Data Export (Post Level) - International Floorball Federation (IFF) - 2021-02.xlsx',sheet_name=None)
FistballDataFrame_2 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Fistball\Facebook\Posts_2_Facebook Insights Data Export (Post Level) - IFA - International Fistball Association - 2021-02-04.xlsx',sheet_name=None)
CEBDataFrame_2 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Billiards\CEB\Facebook\CEB_Post Data_July-Dec 2019.xlsx',sheet_name=None)
UMBDataFrame_2 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Billiards\UMB\Facebook\UMB_Post Data_Jul-Dec 2019.xlsx',sheet_name=None)

# %%
TugOfWarKeyMetrics_2 = TugOfWarDataFrame_2['Key Metrics']
WorldGamesKeyMetrics_2 = WorldGamesDataFrame_2['Key Metrics']
PowerLiftingKeyMetrics_2 = PowerLiftingDataFrame_2['Key Metrics']
KorfballKeyMetrics_2 = KorfballDataFrame_2['Key Metrics']
GymnasticsKeyMetrics_2 = GymnasticsDataFrame_2['Key Metrics']
FloorballKeyMetrics_2 = FloorballDataFrame_2['Key Metrics']
FistballKeyMetrics_2 = FistballDataFrame_2['Posts_2_Facebook Insights Data ']
CEBKeyMetrics_2 = CEBDataFrame_2['Key Metrics']
UMBKeyMetrics_2 = UMBDataFrame_2['Key Metrics']

# %%
listOfKeyMetrics_2 = [TugOfWarKeyMetrics_2,WorldGamesKeyMetrics_2,PowerLiftingKeyMetrics_2,KorfballKeyMetrics_2,GymnasticsKeyMetrics_2,FloorballKeyMetrics_2,FistballKeyMetrics_2, CEBKeyMetrics_2, UMBKeyMetrics_2]
for KeyMetrics_2 in listOfKeyMetrics_2:
    try:
        print(KeyMetrics_2['Type'].value_counts())
    except:
        print("Floorball does not have data for this period")
# Out:
# Status         74
# Photo          49
# Link           37
# SharedVideo    21
# Name: Type, dtype: int64
# Video          36
# Photo          29
# Link           13
# SharedVideo     5
# Name: Type, dtype: int64
# Photo          117
# Video          104
# Link            24
# SharedVideo      8
# Status           2
# Name: Type, dtype: int64
# Photo          228
# Video          211
# Link            28
# SharedVideo     27
# Status           5
# Name: Type, dtype: int64
# Photo          351
# Video          105
# Link            30
# SharedVideo     13
# Status           1
# Name: Type, dtype: int64
# Link           152
# Photo          102
# Video           50
# SharedVideo     29
# Name: Type, dtype: int64
# Photo          84
# Video          66
# SharedVideo     4
# Link            1
# Name: Type, dtype: int64
# Photo          49
# Link            7
# Video           2
# Status          1
# SharedVideo     1
# Name: Type, dtype: int64
# Link    34
# Name: Type, dtype: int64

# %% [markdown]
# # FIRST PERIOD - TYPES

# %%
import pandas as pd
TugOfWarDataFrame_1 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Tug of War\Facebook\TWIF Facebook post data 1 January 2019 - 28 June 2019.xlsx',sheet_name=None)
WorldGamesDataFrame_1 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\The World Games - IWGA\Facebook\Facebook Insights Data Export (Post Level) - The World Games - 2021-02-05.xlsx',sheet_name=None)
PowerLiftingDataFrame_1 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Powerlifting\Facebook\Facebook Insights Data Export (Post Level) - International Powerlifting Federation - IPF - 2021-02-05.xlsx',sheet_name=None)
KorfballDataFrame_1 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Korfball\Facebook\FB Excel Stats\1 Jan 2019 to 28 June 2019\Facebook Insights Data Export (Post Level) - Korfball.org - 1 Jan 2019 to 28 June 2019.xlsx',sheet_name=None)
GymnasticsDataFrame_1 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Gymnastics\Facebook\1 jan 2019 28 june 2019\Facebook Insights Data Export (Post Level) - International Gymnastics Federation - FIG - 2021-02-06 (1).xlsx',sheet_name=None)
FloorballDataFrame_1 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Floorball\Facebook\1st January 2019 - 28th June 2019\Facebook Insights Data Export (Post Level) - International Floorball Federation (IFF) - 2021-02-09.xlsx',sheet_name=None)
FistballDataFrame_1 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Fistball\Facebook\Posts_1_Facebook Insights Data Export (Post Level) - IFA - International Fistball Association - 2021-02-04.xlsx',sheet_name=None)
CEBDataFrame_1 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Billiards\CEB\Facebook\CEB_Post Data_Jan-June 2019.xlsx',sheet_name=None)
UMBDataFrame_1 = pd.read_excel(r'D:\AISTS\Course Related\Research Paper\Federations Data\Billiards\UMB\Facebook\UMB_Post Data_Jan-June 2019.xlsx',sheet_name=None)

# %%
TugOfWarKeyMetrics_1 = TugOfWarDataFrame_1['Key Metrics']
WorldGamesKeyMetrics_1 = WorldGamesDataFrame_1['Key Metrics']
PowerLiftingKeyMetrics_1 = PowerLiftingDataFrame_1['Key Metrics']
KorfballKeyMetrics_1 = KorfballDataFrame_1['Key Metrics']
GymnasticsKeyMetrics_1 = GymnasticsDataFrame_1['Key Metrics']
FloorballKeyMetrics_1 = FloorballDataFrame_1['Key Metrics']
FistballKeyMetrics_1 = FistballDataFrame_1['Posts_1_Facebook Insights Data ']
CEBKeyMetrics_1 = CEBDataFrame_1['Key Metrics']
UMBKeyMetrics_1 = UMBDataFrame_1['Key Metrics']

# %%
listOfKeyMetrics_1 = [TugOfWarKeyMetrics_1,WorldGamesKeyMetrics_1,PowerLiftingKeyMetrics_1,KorfballKeyMetrics_1,GymnasticsKeyMetrics_1,FloorballKeyMetrics_1,FistballKeyMetrics_1, CEBKeyMetrics_1, UMBKeyMetrics_1]
for KeyMetrics_1 in listOfKeyMetrics_1:
    try:
        print(KeyMetrics_1['Type'].value_counts())
    except:
        print("Floorball does not have data for this period")
# Out:
# Photo          66
# Link           27
# SharedVideo    17
# Status         16
# Name: Type, dtype: int64
# Photo          91
# Video          77
# SharedVideo     9
# Link            7
# Status          1
# Name: Type, dtype: int64
# Video          131
# Photo           89
# Link            23
# SharedVideo     15
# Name: Type, dtype: int64
# Photo          278
# Video          162
# Link            29
# SharedVideo     28
# Status           2
# Name: Type, dtype: int64
# Photo          148
# Video           55
# Status           2
# Link             2
# SharedVideo      1
# Name: Type, dtype: int64
# Photo          173
# Link           130
# SharedVideo     27
# Video           25
# Status           1
# Name: Type, dtype: int64
# Photo          31
# Video          14
# Link            6
# SharedVideo     3
# Status          2
# Name: Type, dtype: int64
# Photo          76
# Link            4
# SharedVideo     1
# Name: Type, dtype: int64
# Link    35
# Name: Type, dtype: int64

# %% [markdown]
# # CUMMULATIVE TYPES ACROSS ALL PERIODS
#
# ## Tug Of War
# ### Photo - 119 + 85 + 49 + 66 = 319
# ### Status - 96 + 5 + 74 + 16 = 191
# ### Video - 0 + 0 + 0 + 0 = 0
# ### SharedVideo - 28 + 18 + 21 + 17 = 84
# ### Link - 48 + 22 + 37 + 27 = 134
#
# ## World Games
# ### Photo - 70 + 79 + 29 + 91 = 269
# ### Status - 0 + 0 + 0 + 1 = 1
# ### Video - 86 + 31 + 36 + 77 = 230
# ### SharedVideo - 10 + 5 + 5 + 9 = 29
# ### Link - 20 + 5 + 13 + 7 = 45
#
# ## Powerlifting
# ### Photo - 20 + 16 + 117 + 89 = 242
# ### Status - 2 + 4 + 2 + 0 = 8
# ### Video - 28 + 6 + 104 + 131 = 269
# ### SharedVideo - 15 + 5 + 8 + 15 = 43
# ### Link - 15 + 17 + 24 + 23 = 79
#
# ## Korfball
# ### Photo - 185 + 90 + 117 + 278 = 670
# ### Status - 5 + 1 + 5 + 2 = 13
# ### Video - 149 + 58 + 211 + 162 = 580
# ### SharedVideo - 27 + 23 + 27 + 28 = 105
# ### Link - 38 + 18 + 28 + 29 = 113
#
# ## Gymnastics
# ### Photo - 168 + 107 + 351 + 148 = 774
# ### Status - 0 + 1 + 1 + 2 = 4
# ### Video - 115 + 140 + 105 + 55 = 415
# ### SharedVideo - 10 + 16 + 13 + 1 = 40
# ### Link - 4 + 2 + 30 + 2 = 38
#
# ## Floorball
# ### Photo - 0 + 0 + 102 + 173 = 275
# ### Status - 0 + 0 + 0 + 1 = 1
# ### Video - 0 + 0 + 50 + 25 = 75
# ### SharedVideo - 29 + 27 = 56
# ### Link - 152 + 130 = 282
#
# ## Fistball
# ### Photo - 17 + 30 + 84 + 31 = 162
# ### Status - 2 + 1 + 0 + 2 = 5
# ### Video - 15 + 15 + 66 + 14 = 110
# ### SharedVideo - 1 + 2 + 4 + 3 = 10
# ### Link - 2 + 6 + 1 + 6 = 15
#
# ## CEB
# ### Photo - 53 + 10 + 49 + 76 = 188
# ### Status -  1 + 0 + 1 + 0 = 2
# ### Video - 2 + 0 + 2 + 0 = 4
# ### SharedVideo - 1 + 0 + 1 + 1 = 3
# ### Link - 10 + 1 + 7 + 4 = 22
#
# ## UMB
# ### Photo - 3 + 5 + 0 + 0 = 8
# ### Status - 0 + 0 + 0 + 0 = 0
# ### Video - 0 + 0 + 0 + 0 = 0
# ### SharedVideo - 0 + 0 + 0 + 0 = 0
# ### Link - 11 + 48 + 34 + 35 = 128
